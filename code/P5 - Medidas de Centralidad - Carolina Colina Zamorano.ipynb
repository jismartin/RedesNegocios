# %% [markdown]
# # PRÁCTICA 5 - MEDIDAS DE CENTRALIDAD

# %% [markdown]
# ## 1. Red de football

# %% [markdown]
# ### Estudio de centralidad de los países utilizando aquellas métricas que considere oportunas. En cada una caso, dibuje la red modificando el tamaño y/o el color de los nodos de acuerdo al ranking establecido, y comente brevemente el resultado.

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G = nx.DiGraph()
G.clear()

# %%
G.add_weighted_edges_from([("ARG","ESP",  4 )])
G.add_weighted_edges_from([("ARG","ITA",  9 )])
G.add_weighted_edges_from([("AUT","DEU",  7 )])
G.add_weighted_edges_from([("AUT","ESP",  1 )])
G.add_weighted_edges_from([("AUT","FRA",  1 )])
G.add_weighted_edges_from([("AUT","GBR",  1 )])
G.add_weighted_edges_from([("AUT","ITA",  1 )])
G.add_weighted_edges_from([("BEL","DEU",  2 )])
G.add_weighted_edges_from([("BEL","FRA",  2 )])
G.add_weighted_edges_from([("BEL","ITA",  2 )])
G.add_weighted_edges_from([("BEL","NLD",  2 )])
G.add_weighted_edges_from([("BGR","DEU",  4 )])
G.add_weighted_edges_from([("BGR","ESP",  1 )])
G.add_weighted_edges_from([("BGR","PRT",  1 )])
G.add_weighted_edges_from([("BGR","TUR",  4 )])
G.add_weighted_edges_from([("BRA","ESP",  4 )])
G.add_weighted_edges_from([("BRA","FRA",  1 )])
G.add_weighted_edges_from([("BRA","ITA",  5 )])
G.add_weighted_edges_from([("BRA","JPN",  1 )])
G.add_weighted_edges_from([("BRA","PRT",  1 )])
G.add_weighted_edges_from([("CHL","ARG",  1 )])
G.add_weighted_edges_from([("CHL","ITA",  1 )])
G.add_weighted_edges_from([("CHL","USA",  1 )])
G.add_weighted_edges_from([("CMR","AUT",  1 )])
G.add_weighted_edges_from([("CMR","DEU",  1 )])
G.add_weighted_edges_from([("CMR","ESP",  2 )])
G.add_weighted_edges_from([("CMR","FRA",  7 )])
G.add_weighted_edges_from([("CMR","GRE",  1 )])
G.add_weighted_edges_from([("CMR","ITA",  2 )])
G.add_weighted_edges_from([("CMR","JPN",  2 )])
G.add_weighted_edges_from([("CMR","PRT",  2 )])
G.add_weighted_edges_from([("CMR","TUR",  2 )])
G.add_weighted_edges_from([("COL","ARG",  3 )])
G.add_weighted_edges_from([("COL","BRA",  2 )])
G.add_weighted_edges_from([("COL","ESP",  1 )])
G.add_weighted_edges_from([("COL","ITA",  1 )])
G.add_weighted_edges_from([("COL","USA",  2 )])
G.add_weighted_edges_from([("DEU","ESP",  1 )])
G.add_weighted_edges_from([("DEU","FRA",  1 )])
G.add_weighted_edges_from([("DEU","ITA",  2 )])
G.add_weighted_edges_from([("DNK","DEU",  3 )])
G.add_weighted_edges_from([("DNK","ESP",  1 )])
G.add_weighted_edges_from([("DNK","GBR",  6 )])
G.add_weighted_edges_from([("DNK","ITA",  1 )])
G.add_weighted_edges_from([("DNK","NLD",  1 )])
G.add_weighted_edges_from([("DNK","SCO",  3 )])
G.add_weighted_edges_from([("DNK","TUR",  1 )])
G.add_weighted_edges_from([("HRV","AUT",  1 )])
G.add_weighted_edges_from([("HRV","DEU",  2 )])
G.add_weighted_edges_from([("HRV","ESP",  4 )])
G.add_weighted_edges_from([("HRV","GBR",  2 )])
G.add_weighted_edges_from([("HRV","ITA",  4 )])
G.add_weighted_edges_from([("HRV","TUR",  1 )])
G.add_weighted_edges_from([("IRN","DEU",  3 )])
G.add_weighted_edges_from([("ITA","ESP",  2 )])
G.add_weighted_edges_from([("ITA","FRA",  1 )])
G.add_weighted_edges_from([("ITA","GBR",  2 )])
G.add_weighted_edges_from([("JAM","GBR",  7 )])
G.add_weighted_edges_from([("KOR","FRA",  1 )])
G.add_weighted_edges_from([("KOR","JPN",  4 )])
G.add_weighted_edges_from([("MAR","DEU",  3 )])
G.add_weighted_edges_from([("MAR","ESP",  4 )])
G.add_weighted_edges_from([("MAR","FRA",  1 )])
G.add_weighted_edges_from([("MAR","ITA",  1 )])
G.add_weighted_edges_from([("MAR","PRT",  3 )])
G.add_weighted_edges_from([("MAR","TUN",  1 )])
G.add_weighted_edges_from([("NGA","BEL",  2 )])
G.add_weighted_edges_from([("NGA","CHE",  1 )])
G.add_weighted_edges_from([("NGA","DEU",  1 )])
G.add_weighted_edges_from([("NGA","ESP",  4 )])
G.add_weighted_edges_from([("NGA","FRA",  3 )])
G.add_weighted_edges_from([("NGA","ITA",  2 )])
G.add_weighted_edges_from([("NGA","NLD",  3 )])
G.add_weighted_edges_from([("NGA","TUR",  3 )])
G.add_weighted_edges_from([("NGA","USA",  1 )])
G.add_weighted_edges_from([("NGA","ZAF",  1 )])
G.add_weighted_edges_from([("NLD","DEU",  1 )])
G.add_weighted_edges_from([("NLD","ESP",  5 )])
G.add_weighted_edges_from([("NLD","GBR",  4 )])
G.add_weighted_edges_from([("NLD","ITA",  2 )])
G.add_weighted_edges_from([("NOR","DEU",  3 )])
G.add_weighted_edges_from([("NOR","ESP",  1 )])
G.add_weighted_edges_from([("NOR","GBR", 12 )])
G.add_weighted_edges_from([("NOR","GRE",  2 )])
G.add_weighted_edges_from([("NOR","ITA",  1 )])
G.add_weighted_edges_from([("NOR","SCO",  3 )])
G.add_weighted_edges_from([("PRY","BRA", 10 )])
G.add_weighted_edges_from([("PRY","ESP",  2 )])
G.add_weighted_edges_from([("PRY","MEX",  1 )])
G.add_weighted_edges_from([("ROM","BEL",  1 )])
G.add_weighted_edges_from([("ROM","DEU",  2 )])
G.add_weighted_edges_from([("ROM","ESP",  6 )])
G.add_weighted_edges_from([("ROM","GBR",  2 )])
G.add_weighted_edges_from([("ROM","GRE",  2 )])
G.add_weighted_edges_from([("ROM","NLD",  1 )])
G.add_weighted_edges_from([("ROM","TUR",  4 )])
G.add_weighted_edges_from([("SCO","FRA",  1 )])
G.add_weighted_edges_from([("SCO","GBR",  7 )])
G.add_weighted_edges_from([("TUN","DEU",  2 )])
G.add_weighted_edges_from([("TUN","FRA",  3 )])
G.add_weighted_edges_from([("USA","DEU",  2 )])
G.add_weighted_edges_from([("USA","GBR",  2 )])
G.add_weighted_edges_from([("USA","NLD",  1 )])
G.add_weighted_edges_from([("YUG","DEU",  1 )])
G.add_weighted_edges_from([("YUG","ESP",  9 )])
G.add_weighted_edges_from([("YUG","FRA",  1 )])
G.add_weighted_edges_from([("YUG","GBR",  1 )])
G.add_weighted_edges_from([("YUG","ITA",  7 )])
G.add_weighted_edges_from([("YUG","JPN",  2 )])
G.add_weighted_edges_from([("ZAF","AUT",  1 )])
G.add_weighted_edges_from([("ZAF","CHE",  1 )])
G.add_weighted_edges_from([("ZAF","DEU",  2 )])
G.add_weighted_edges_from([("ZAF","ESP",  2 )])
G.add_weighted_edges_from([("ZAF","FRA",  1 )])
G.add_weighted_edges_from([("ZAF","GBR",  4 )])
G.add_weighted_edges_from([("ZAF","ITA",  1 )])
G.add_weighted_edges_from([("ZAF","NLD",  2 )])
G.add_weighted_edges_from([("ZAF","TUR",  3 )])

# %% [markdown]
# ## DEGREE CENTRALITY

# %%
FutbolDegree=np.array([x for x in nx.centrality.degree_centrality(G).values()])
# Visualizo la lista según el degree ordenada por el segundo campo (x:x[1])
sorted(list(nx.degree_centrality(G).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('ITA', 0.5588235294117647),
#  ('DEU', 0.5588235294117647),
#  ('ESP', 0.5294117647058824),
#  ('FRA', 0.38235294117647056),
#  ('GBR', 0.3529411764705882),
#  ('NLD', 0.29411764705882354),
#  ('NGA', 0.29411764705882354),
#  ('ZAF', 0.29411764705882354),
#  ('CMR', 0.2647058823529412),
#  ('AUT', 0.23529411764705882),
#  ('TUR', 0.20588235294117646),
#  ('BRA', 0.20588235294117646),
#  ('DNK', 0.20588235294117646),
#  ('ROM', 0.20588235294117646),
#  ('BEL', 0.1764705882352941),
#  ('USA', 0.1764705882352941),
#  ('HRV', 0.1764705882352941),
#  ('MAR', 0.1764705882352941),
#  ('NOR', 0.1764705882352941),
#  ('YUG', 0.1764705882352941),
#  ('COL', 0.14705882352941177),
#  ('ARG', 0.11764705882352941),
#  ('BGR', 0.11764705882352941),
#  ('PRT', 0.11764705882352941),
#  ('JPN', 0.11764705882352941),
#  ('SCO', 0.11764705882352941),
#  ('CHL', 0.08823529411764705),
#  ('GRE', 0.08823529411764705),
#  ('TUN', 0.08823529411764705),
#  ('PRY', 0.08823529411764705),
# ...

# %%
pos=nx.kamada_kawai_layout(G)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(20,20))
nx.draw(G,pos,with_labels=True, node_color='skyblue', alpha=0.9, node_size=FutbolDegree*15000)

# %% [markdown]
# ### Esta medida se centra en el número de enlaces con otros nodos. Los nodos que están al principio de la lista, o los que se visualizan de mayor tamaño en el grado son los países que más jugadores importan. Vemos qué a los nodos de mayor grado les llegan más enlaces.

# %% [markdown]
# ## EIGENVECTOR CENTRALITY

# %%
FutbolEigenvector=np.array([x for x in nx.centrality.eigenvector_centrality_numpy(G).values()])
sorted(list(nx.eigenvector_centrality_numpy(G).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('ESP', 0.5773641569947805),
#  ('FRA', 0.57736415699329702),
#  ('GBR', 0.57732249107502909),
#  ('ITA', 4.1665920693212413e-05),
#  ('PRT', 1.2181644581943376e-12),
#  ('JPN', 1.218136702618722e-12),
#  ('DEU', 4.1987247012542649e-13),
#  ('BRA', 1.3877787807814459e-16),
#  ('TUN', 1.1102230246251568e-16),
#  ('MEX', 9.7144514654701222e-17),
#  ('ARG', 8.3266726846886765e-17),
#  ('SCO', 5.5511151231257839e-17),
#  ('KOR', 5.5511151231257839e-17),
#  ('GRE', 2.9490299091605727e-17),
#  ('DNK', 2.775557561562892e-17),
#  ('ROM', 2.775557561562892e-17),
#  ('NGA', 1.387778780781446e-17),
#  ('BGR', -0.0),
#  ('USA', -0.0),
#  ('CMR', -0.0),
#  ('MAR', -0.0),
#  ('ZAF', -8.673617379884037e-18),
#  ('IRN', -1.387778780781446e-17),
#  ('JAM', -1.387778780781446e-17),
#  ('CHL', -2.775557561562892e-17),
#  ('COL', -2.775557561562892e-17),
#  ('PRY', -5.5511151231257839e-17),
#  ('YUG', -5.5511151231257839e-17),
#  ('HRV', -8.3266726846886765e-17),
#  ('NOR', -8.3266726846886765e-17),
# ...

# %%
# Da un error por los que tienen valores negativos
pos=nx.kamada_kawai_layout(G)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(20,20))
nx.draw(G,pos,with_labels=True, node_color='yellow', alpha=0.9, node_size=FutbolEigenvector*15000)
# Out:
# C:\Users\Carol\Anaconda3\lib\site-packages\matplotlib\collections.py:836: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ### Eigenvector Centrality se basa en que la importancia de un nodo depende de la importancia de los nodos que le apuntan, es decir, un nodo es importante si los que le apuntan lo son.
# ### En este caso los tres países que destacan (España, Francia y Gran Bretaña) son los que más jugadores importan de las los países más importantes.

# %% [markdown]
# ## PAGERANK CENTRALITY

# %%
FutbolPagerank=np.array([x for x in nx.pagerank(G).values()])
sorted(list(nx.pagerank(G).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('ESP', 0.11538530201425039),
#  ('GBR', 0.10857892316820483),
#  ('ITA', 0.09626240628440098),
#  ('FRA', 0.07425675853712015),
#  ('DEU', 0.0730565685477357),
#  ('TUR', 0.029445744482205556),
#  ('JPN', 0.02902363816645246),
#  ('BRA', 0.027059627469620227),
#  ('NLD', 0.02676582049880349),
#  ('ARG', 0.02300573394654903),
#  ('USA', 0.022213243483392254),
#  ('PRT', 0.021978093144964437),
#  ('SCO', 0.018726960863510816),
#  ('GRE', 0.017830230887728588),
#  ('AUT', 0.016964161516713643),
#  ('BEL', 0.016566748933400228),
#  ('CHE', 0.01604289135329389),
#  ('TUN', 0.015644716759919748),
#  ('MEX', 0.015644716759919748),
#  ('ZAF', 0.015278951930770467),
#  ('BGR', 0.014684584083402886),
#  ('CHL', 0.014684584083402886),
#  ('CMR', 0.014684584083402886),
#  ('COL', 0.014684584083402886),
#  ('DNK', 0.014684584083402886),
#  ('HRV', 0.014684584083402886),
#  ('IRN', 0.014684584083402886),
#  ('JAM', 0.014684584083402886),
#  ('KOR', 0.014684584083402886),
# ...

# %%
pos=nx.kamada_kawai_layout(G)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(20,20))
nx.draw(G,pos,with_labels=True, node_color='violet', alpha=0.9, node_size=FutbolPagerank*150000)

# %% [markdown]
# #### PageRank evalúa el prestigio de un nodo. Si un nodo esprestigioso convierte en prestigioso a aquel al que apunta. Los nodos más prestigiosos serán aquellos que están muy relacionados.
# #### Si un nodo prestigioso está enlazado con muchos nodos, reparte esa relevancia. Por ello vemos que los países con mayor PageRank importan jugadores de países de más prestigio. Y exportan jugadores a países repartiendo ese prestigio.

# %% [markdown]
# ## CLOSENESS CENTRALITY

# %%
FutbolCloseness=np.array([x for x in nx.centrality.closeness_centrality(G).values()])
sorted(list(nx.closeness_centrality(G).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('ESP', 0.555672268907563),
#  ('ITA', 0.5084033613445378),
#  ('FRA', 0.4968203497615263),
#  ('DEU', 0.47647058823529415),
#  ('GBR', 0.43767507002801126),
#  ('TUR', 0.20588235294117646),
#  ('NLD', 0.18823529411764706),
#  ('PRT', 0.1323529411764706),
#  ('JPN', 0.1323529411764706),
#  ('AUT', 0.09411764705882353),
#  ('USA', 0.08823529411764706),
#  ('GRE', 0.08823529411764706),
#  ('ARG', 0.058823529411764705),
#  ('BEL', 0.058823529411764705),
#  ('BRA', 0.058823529411764705),
#  ('SCO', 0.058823529411764705),
#  ('CHE', 0.058823529411764705),
#  ('TUN', 0.029411764705882353),
#  ('ZAF', 0.029411764705882353),
#  ('MEX', 0.029411764705882353),
#  ('BGR', 0.0),
#  ('CHL', 0.0),
#  ('CMR', 0.0),
#  ('COL', 0.0),
#  ('DNK', 0.0),
#  ('HRV', 0.0),
#  ('IRN', 0.0),
#  ('JAM', 0.0),
#  ('KOR', 0.0),
#  ('MAR', 0.0),
#  ('NGA', 0.0),
#  ('NOR', 0.0),
#  ('PRY', 0.0),
#  ('ROM', 0.0),
#  ('YUG', 0.0)]

# %%
pos=nx.kamada_kawai_layout(G)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(20,20))
nx.draw(G,pos,with_labels=True, node_color='orange', alpha=0.9, node_size=FutbolCloseness*10000)

# %% [markdown]
# #### Closeness Centrality estudia qué nodo está más próximo a todos los demás. No creo que sea una medida de centralidad a tener en cuenta para el estudio.

# %% [markdown]
# ## BETWEENNESS CENTRALITY

# %%
FutbolBetweenness=np.array([x for x in nx.centrality.betweenness_centrality(G).values()])
sorted(list(nx.betweenness_centrality(G).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('ITA', 0.013443256090314914),
#  ('DEU', 0.013071895424836602),
#  ('BRA', 0.0066844919786096255),
#  ('USA', 0.004679144385026738),
#  ('NLD', 0.0021538918597742126),
#  ('ZAF', 0.0011140819964349374),
#  ('AUT', 0.000742721330956625),
#  ('BEL', 0.000742721330956625),
#  ('SCO', 0.0005941770647653),
#  ('ARG', 0.000445632798573975),
#  ('ESP', 0.0),
#  ('FRA', 0.0),
#  ('GBR', 0.0),
#  ('BGR', 0.0),
#  ('PRT', 0.0),
#  ('TUR', 0.0),
#  ('JPN', 0.0),
#  ('CHL', 0.0),
#  ('CMR', 0.0),
#  ('GRE', 0.0),
#  ('COL', 0.0),
#  ('DNK', 0.0),
#  ('HRV', 0.0),
#  ('IRN', 0.0),
#  ('JAM', 0.0),
#  ('KOR', 0.0),
#  ('MAR', 0.0),
#  ('TUN', 0.0),
#  ('NGA', 0.0),
#  ('CHE', 0.0),
#  ('NOR', 0.0),
#  ('PRY', 0.0),
#  ('MEX', 0.0),
#  ('ROM', 0.0),
#  ('YUG', 0.0)]

# %%
pos=nx.kamada_kawai_layout(G)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(20,20))
nx.draw(G,pos,with_labels=True, node_color='teal', alpha=0.9, node_size=FutbolBetweenness*800000)

# %% [markdown]
# #### Los nodos con mayor Betweenness influyen más en la transmisión de información y hacen de enlace entre grupos aislados. Como este no es el caso, creo que esta medida de centralidad tampoco se debería tener en cuenta para estudiar la red de Fútbol.

# %% [markdown]
# ## 2. Red de familias de florentinas del renacimiento

# %% [markdown]
# ### Estudio de centralidad de las familias utilizando aquellas métricas que considere oportunas. Escoja aquella métrica de centralidad que mejor explique el poder de los Medici frente a la familia rival de los Pazzi

# %%
Gfam = nx.DiGraph()
Gfam.clear()

# %% [markdown]
# ### EIGENVECTOR CENTRALITY

# %%
Gfam =nx.florentine_families_graph()
FamiliasEigenvector=np.array([x for x in nx.centrality.eigenvector_centrality_numpy(Gfam).values()])
sorted(list(nx.eigenvector_centrality(Gfam).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('Medici', 0.4303154258349923),
#  ('Strozzi', 0.3559730326460451),
#  ('Ridolfi', 0.3415544259074365),
#  ('Tornabuoni', 0.325846704169574),
#  ('Guadagni', 0.2891171573226501),
#  ('Bischeri', 0.2827943958713356),
#  ('Peruzzi', 0.2757224374104833),
#  ('Castellani', 0.2590200378423514),
#  ('Albizzi', 0.2439605296754477),
#  ('Barbadori', 0.2117057470647985),
#  ('Salviati', 0.14592084164171834),
#  ('Acciaiuoli', 0.1321573195285342),
#  ('Lamberteschi', 0.08879253113499548),
#  ('Ginori', 0.0749245316027793),
#  ('Pazzi', 0.044814939703863084)]

# %% [markdown]
# #### Con esta medida de centralidad, podemos ver que la familia Medici estaba mejor relacionada con las familias más prestigiosas. La familia Pazzi en cambio era la peor relacionada

# %%
pos=nx.kamada_kawai_layout(Gfam)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(10,10))
nx.draw(Gfam,pos,with_labels=True, node_color='skyblue', alpha=0.9, node_size=FamiliasEigenvector*15000)

# %% [markdown]
# ### CLOSENESS CENTRALITY

# %%
FamiliasCloseness=np.array([x for x in nx.pagerank(Gfam).values()])
sorted(list(nx.closeness_centrality(Gfam).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('Medici', 0.56),
#  ('Ridolfi', 0.5),
#  ('Tornabuoni', 0.4827586206896552),
#  ('Albizzi', 0.4827586206896552),
#  ('Guadagni', 0.4666666666666667),
#  ('Strozzi', 0.4375),
#  ('Barbadori', 0.4375),
#  ('Bischeri', 0.4),
#  ('Castellani', 0.3888888888888889),
#  ('Salviati', 0.3888888888888889),
#  ('Acciaiuoli', 0.3684210526315789),
#  ('Peruzzi', 0.3684210526315789),
#  ('Ginori', 0.3333333333333333),
#  ('Lamberteschi', 0.32558139534883723),
#  ('Pazzi', 0.2857142857142857)]

# %% [markdown]
# #### Con esta medida de centralidad comprobamos la cerncanía de unas familias con otras. Como se puede ver, la familia Medici posee una mayor cercanía con otras familias que los Pazzi, lo que ayuda a una mejor comunicación entre ellas.

# %%
pos=nx.kamada_kawai_layout(Gfam)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(10,10))
nx.draw(Gfam,pos,with_labels=True, node_color='orange', alpha=0.9, node_size=FamiliasCloseness*15000)

# %% [markdown]
# ### BETWEENNESS CENTRALITY

# %%
Gfam =nx.florentine_families_graph()
FamiliasBetweenness=np.array([x for x in nx.centrality.betweenness_centrality(Gfam).values()])
sorted(list(nx.nx.centrality.betweenness_centrality(Gfam).items()), key=lambda x:x[1], reverse=True)
# Out:
# [('Medici', 0.521978021978022),
#  ('Guadagni', 0.2545787545787546),
#  ('Albizzi', 0.21245421245421245),
#  ('Salviati', 0.14285714285714288),
#  ('Ridolfi', 0.11355311355311355),
#  ('Bischeri', 0.1043956043956044),
#  ('Strozzi', 0.10256410256410257),
#  ('Barbadori', 0.09340659340659341),
#  ('Tornabuoni', 0.09157509157509157),
#  ('Castellani', 0.05494505494505495),
#  ('Peruzzi', 0.02197802197802198),
#  ('Acciaiuoli', 0.0),
#  ('Pazzi', 0.0),
#  ('Ginori', 0.0),
#  ('Lamberteschi', 0.0)]

# %% [markdown]
# #### Con Betweenness centrality vemos quíen es la familia más alejada de la red: los Pazzi. En consecuencia, los Medici inluyen en mayor medida en la transmisión de información, así como la información que reciben.
# #### Los Pazzi, estarían más aislados de la información y relaciones entre familias que los Medici.

# %%
pos=nx.kamada_kawai_layout(Gfam)
# Amplío el grafo para que se vea mejor
plt.figure(figsize=(10,10))
nx.draw(Gfam,pos,with_labels=True, node_color='skyblue', alpha=0.9, node_size=FamiliasBetweenness*15000)
